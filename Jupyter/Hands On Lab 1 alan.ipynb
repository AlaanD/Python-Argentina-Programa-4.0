# %%
#Importacion del archivo

import pandas as pd

df = pd.read_csv("D:/Alan/Cursos/Argentina programa 4.0/Python Argentina Programa 4.0/Jupyter/AB_NYC_2019.csv", sep = ",")

# %%
#Imprimir las primeras 5 filas del df
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood   latitude   longitude  \
# 0         John            Brooklyn    Kensington  4,064,749  -7,397,237
# 1     Jennifer           Manhattan       Midtown  4,075,362  -7,398,377
# 2    Elisabeth           Manhattan        Harlem  4,080,902    -739,419
# 3  LisaRoxanne            Brooklyn  Clinton Hill  4,068,514  -7,395,976
# 4        Laura           Manhattan   East Harlem  4,079,851  -7,394,399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#Ultimos 5 registros
df.tail()
# Out:
#              id                                               name    host_id  \
# 33562  26557901                               Park Slope, Brooklyn  199702366
# 33563  26558970  Fifth Element: 7bd, private home.FREE CANCELLA...  143979755
# 33564  26559223  Charming Williamsburg Apartment,  next to trai...   18210699
# 33565  26559313               2 Stops from Manhattan in Trendy LIC  155924492
# 33566  26559476          Warm and Cozy Bedroom ~ 15 minutes to JFK   72746827
#
#                 host_name neighbourhood_group     neighbourhood   latitude  \
# 33562               Anuar            Brooklyn       South Slope  4,066,625
# 33563               Edwin               Bronx    Pelham Gardens  4,086,239
# 33564              Leanne            Brooklyn      Williamsburg  4,071,106
# 33565           Christina              Queens  Long Island City  4,075,311
# 33566  Jeffrey & Casandra              Queens         Bayswater  4,061,036
#
# ...

# %%
#Dimensiones del Dataset
print(df.shape)
# Out:
# (33567, 16)

# %%
#Obtener la totalidad de registros por columnas ---> Analizar valores missings
df.count()
# Out:
# id                                33567
# name                              33551
# host_id                           33567
# host_name                         33547
# neighbourhood_group               33567
# neighbourhood                     33567
# latitude                          33567
# longitude                         33567
# room_type                         33567
# price                             33567
# minimum_nights                    33567
# number_of_reviews                 33567
# last_review                       28117
# reviews_per_month                 28117
# calculated_host_listings_count    33567
# availability_365                  33567
# dtype: int64

# %%
#Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33567 entries, 0 to 33566
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              33567 non-null  int64
#  1   name                            33551 non-null  object
#  2   host_id                         33567 non-null  int64
#  3   host_name                       33547 non-null  object
#  4   neighbourhood_group             33567 non-null  object
#  5   neighbourhood                   33567 non-null  object
#  6   latitude                        33567 non-null  object
#  7   longitude                       33567 non-null  object
#  8   room_type                       33567 non-null  object
#  9   price                           33567 non-null  int64
#  10  minimum_nights                  33567 non-null  int64
#  11  number_of_reviews               33567 non-null  int64
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                           object
# longitude                          object
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
#Verificar la estructura del dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Listar los nombres de las columnas del dataset
print(df.columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#Eliminar columnas: id, host_name, last_review
columns_to_drop = ['id', 'host_name', 'last_review']
df.drop(columns_to_drop, axis = "columns", inplace = True)
#inplace = True sirve para sobreescribir el objeto

# %%
#Volvemos a hacer un shape
print(df.shape)
# Out:
# (33567, 13)

# %%
#Completar valores missings
df.fillna({'reviews_per_month': 0}, inplace = True)

# %%
#Precio menor a 100 dolares
df[df['price']<100]
# Out:
#                                                     name    host_id  \
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 6                                        BlissArtsSpace!       7356
# 7                        Large Furnished Room Near B'way       8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# ...                                                  ...        ...
# 33560               Cozy private Room in 2 bedrooms appt  152047633
# 33562                               Park Slope, Brooklyn  199702366
# 33563  Fifth Element: 7bd, private home.FREE CANCELLA...  143979755
# 33564  Charming Williamsburg Apartment,  next to trai...   18210699
# 33566          Warm and Cozy Bedroom ~ 15 minutes to JFK   72746827
#
#       neighbourhood_group       neighbourhood   latitude   longitude  \
# 3                Brooklyn        Clinton Hill  4,068,514  -7,395,976
# ...

# %%
#Precio mayores a 100 dolares
df[df['price']>100]
# Out:
#                                                     name    host_id  \
# 0                     Clean & quiet apt home by the park       2787
# 1                                  Skylit Midtown Castle       2845
# 2                    THE VILLAGE OF HARLEM....NEW YORK !       4632
# 5              Large Cozy 1 BR Apartment In Midtown East       7322
# 9                     Cute & Cozy Lower East Side 1 bdrm       7549
# ...                                                  ...        ...
# 33555  Beach Street Loft -  Surf Rockaway Beach, NYC,...   10457300
# 33556                            Immaculate and Spacious   20444038
# 33559              Midtown NYC: High End Resort Sleeps 2  172190160
# 33561   Quiet and Cozy Brooklyn Home in Perfect Location    1840698
# 33565               2 Stops from Manhattan in Trendy LIC  155924492
#
#       neighbourhood_group     neighbourhood   latitude   longitude  \
# 0                Brooklyn        Kensington  4,064,749  -7,397,237
# ...

# %%
#Listado de los 10 reviews
df.nlargest(10, 'number_of_reviews')
# Out:
#                                                     name   host_id  \
# 11759                            Room near JFK Queen Bed  47621202
# 2031                          Great Bedroom in Manhattan   4734398
# 2030                      Beautiful Bedroom in Manhattan   4734398
# 2015                        Private Bedroom in Manhattan   4734398
# 13495                            Room Near JFK Twin Beds  47621202
# 10623                  Steps away from Laguardia airport  37312959
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !   2369681
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 4870                  Private brownstone studio Brooklyn  12949460
# 471                      LG Private Room/Family Friendly    792159
#
#       neighbourhood_group    neighbourhood   latitude   longitude  \
# 11759              Queens          Jamaica    406,673  -7,376,831
# 2031            Manhattan           Harlem  4,082,085  -7,394,025
# ...

# %%
#10 mejores vecindarios
df['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          2899
# Bedford-Stuyvesant    2509
# Harlem                1957
# Bushwick              1633
# Upper West Side       1487
# East Village          1400
# Upper East Side       1307
# Crown Heights         1184
# Hell's Kitchen        1165
# Midtown                912
# Name: neighbourhood, dtype: int64

# %%
#La misma informacion que antes pero ahora con un grafico!
df['neighbourhood'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >
